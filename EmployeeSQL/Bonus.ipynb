# %%
from sqlalchemy import create_engine
from config import username, password
engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/SQL Challenge')
connection = engine.connect()
import pandas as pd
import matplotlib.pyplot as plt

# %%
employees = pd.read_sql('select * from employees', connection)

salaries = pd.read_sql('select * from salaries', connection)

titles = pd.read_sql('select * from titles', connection)

# %%
salaries
# Out:
#         emp_no  salary
# 0        10001   60117
# 1        10002   65828
# 2        10003   40006
# 3        10004   40054
# 4        10005   78228
# ...        ...     ...
# 300019  499995   40000
# 300020  499996   58058
# 300021  499997   49597
# 300022  499998   40000
# 300023  499999   63707
#
# [300024 rows x 2 columns]

# %%
titles
# Out:
#   title_id               title
# 0    s0001               Staff
# 1    s0002        Senior Staff
# 2    e0001  Assistant Engineer
# 3    e0002            Engineer
# 4    e0003     Senior Engineer
# 5    e0004    Technique Leader
# 6    m0001             Manager

# %%
employees_salaries = employees.merge(salaries, on = 'emp_no')
employees_salaries
# Out:
#         emp_no emp_title_id  birth_date   first_name  last_name sex  \
# 0       473302        s0001  1953-07-25     Hideyuki   Zallocco   M
# 1       475053        e0002  1954-11-18        Byong  Delgrande   F
# 2        57444        e0002  1958-01-30        Berry       Babb   F
# 3       421786        s0001  1957-09-28        Xiong   Verhoeff   M
# 4       282238        e0003  1952-10-28   Abdelkader    Baumann   F
# ...        ...          ...         ...          ...        ...  ..
# 300019  464231        s0001  1958-08-14  Constantino    Eastman   M
# 300020  255832        e0002  1955-05-08       Yuping     Dayang   F
# 300021   76671        s0001  1959-06-09       Ortrud   Plessier   M
# 300022  264920        s0001  1959-09-22        Percy   Samarati   F
# 300023  464503        s0002  1964-05-31       Arvind  Slobodova   M
#
#          hire_date  salary
# 0       1990-04-28   40000
# 1       1991-09-07   53422
# 2       1992-03-21   48973
# 3       1987-11-26   40000
# ...

# %%
employees_salaries_title = employees_salaries.merge(titles, left_on = 'emp_title_id', right_on = 'title_id')
employees_salaries_title
# Out:
#         emp_no emp_title_id  birth_date  first_name   last_name sex  \
# 0       473302        s0001  1953-07-25    Hideyuki    Zallocco   M
# 1       421786        s0001  1957-09-28       Xiong    Verhoeff   M
# 2       273487        s0001  1957-04-14   Christoph     Parfitt   M
# 3       246449        s0001  1958-03-23       Subbu  Bultermann   F
# 4        48085        s0001  1964-01-19  Venkatesan        Gilg   M
# ...        ...          ...         ...         ...         ...  ..
# 300019  111400        m0001  1959-11-09        Arie     Staelin   M
# 300020  111133        m0001  1955-03-16       Hauke       Zhang   M
# 300021  110085        m0001  1959-10-28        Ebru       Alpin   M
# 300022  110386        m0001  1953-10-04        Shem      Kieras   M
# 300023  111784        m0001  1956-06-14       Marjo  Giarratana   F
#
#          hire_date  salary title_id    title
# 0       1990-04-28   40000    s0001    Staff
# 1       1987-11-26   40000    s0001    Staff
# ...

# %%
titles_salaries = employees_salaries_title[["salary", "title"]]
titles_salaries
# Out:
#         salary    title
# 0        40000    Staff
# 1        40000    Staff
# 2        56087    Staff
# 3        87084    Staff
# 4        63016    Staff
# ...        ...      ...
# 300019   72446  Manager
# 300020   71148  Manager
# 300021   60026  Manager
# 300022   40000  Manager
# 300023   40000  Manager
#
# [300024 rows x 2 columns]

# %%
titles_salaries_group = titles_salaries.groupby("title")["salary"].mean()

# %%
titles_salaries.hist(column = "salary")
plt.xlabel("Salary Ranges")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
titles_salaries_group.plot.bar()
plt.xlabel("Titles")
plt.ylabel()
# Out:
# Text(0.5, 0, '')
